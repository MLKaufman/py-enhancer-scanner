# %% [markdown]
# # pyEnhancerScanner Package Example Notebook

# %%
from pyEnhancerScan import EnhancerScan

scanobject = EnhancerScan()
# Out:
# pyEnhancerScanner version 0.4 beta
#
# The following tracks are locally available:
# ['GSE102092_ATAC-Dev-Ret_E_N-E14.5.free.mm10.bw.bw', 'GSE102092_ATAC-Dev-Ret_I_N-P0.free.mm10.bw.bw', 'GSE102092_ATAC-Dev-Ret_M_N-P14.free.bw', 'GSE102092_ATAC-Dev-Ret_M_N-P21.free.mm10.bw.bw', 'mm10.60way.phastCons60wayPlacental.bw', 'mm9P14atac.bw']
#
# To download additional tracks, use the download_tracks() function.

# %%
scanobject.download_tracks()
# Out:
# External Track List:
#                            Track_Name Genome   Size  \
# 0  Mouse 60way Placental Conservation   mm10   4.2G
# 1                      Mouse P14 ATAC    mm9   150M
# 2                Mouse IPSC Cone ATAC   mm10     ??
#
#                                             URL_Path
# 0   http://hgdownload.cse.ucsc.edu/goldenpath/mm1...
# 1   https://www.ncbi.nlm.nih.gov/geo/download/?ac...
# 2   https://olucdenver-my.sharepoint.com/:u:/g/pe...
#
# To download one of these tracks, use download_tracks(track_num=X) where X is the track number / index.
# You can specify your own download url by download_tracks(url='X').

# %%
scanobject.download_tracks(track_num=2)
# Out:
# ...
# 403

# %%
scanobject.load_track('GSE102092_ATAC-Dev-Ret_M_N-P14.free.bw', 'mm10')
scanobject.enhancer_scanner('chr14', 48654006, 48677663)
scanobject.plot_detected_enhancers()
# Out:
# Max peak height in this range:  6.824460029602051
# Mean peak height in this range:  0.46370297000870825
# Median peak height in this range:  0.0
#
# Max peak height across whole track:  1567
# Minumum peak height across whole track:  0
#
# Using auto detection of peak height:  1.7061150074005127
#
# Total Peaks Detected: 15
# Final Passed Merge/Filters: 11

# %%
scanobject.load_track('GSE102092_ATAC-Dev-Ret_M_N-P21.free.mm10.bw.bw', 'mm10')
scanobject.enhancer_scanner('chr14', 48654006, 48677663)
scanobject.plot_detected_enhancers()
# Out:
# Max peak height in this range:  104.09100341796875
# Mean peak height in this range:  4.404409213149337
# Median peak height in this range:  1.084280014038086
#
# Max peak height across whole track:  1188
# Minumum peak height across whole track:  0
#
# Using auto detection of peak height:  26.022750854492188
#
# Total Peaks Detected: 5
# Final Passed Merge/Filters: 4
