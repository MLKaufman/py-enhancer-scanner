# %% [markdown]
# # pyEnhancerScanner Package Example Notebook

# %%
from pyEnhancerScan import EnhancerScan

scanobject = EnhancerScan()
# Out:
# pyEnhancerScanner version 0.4 beta
#
# The following tracks are locally available:
# GSE102092_ATAC-Dev-Ret_E_N-E14.5.free.mm10.bw.bw
# GSE102092_ATAC-Dev-Ret_I_N-P0.free.mm10.bw.bw
# GSE102092_ATAC-Dev-Ret_M_N-P14.free.bw
# GSE102092_ATAC-Dev-Ret_M_N-P21.free.mm10.bw.bw
# mm10.60way.phastCons60wayPlacental.bw
#
# To download additional tracks, use the download_tracks() function.

# %%
scanobject.download_tracks()
# Out:
# External Track List:
#                                  Track_Name Genome      Size
# 0  mm10.60way.phastCons60wayPlacental        mm10   4.2G
# 1  GSE102092_ATAC-Dev-Ret_E_N-E14.5.free.bw  mm10   220Mb
# 2  GSE102092_ATAC-Dev-Ret_E_N-E14.5.free.bw  mm9    228.9 Mb
# 3  GSE102092_ATAC-Dev-Ret_E_N-E17.5.free.bw  mm9    217.4 Mb
# 4  GSE102092_ATAC-Dev-Ret_I_N-P0.free.bw     mm9    262.6 Mb
# 5  GSE102092_ATAC-Dev-Ret_I_N-P3.free.bw     mm9    241.6 Mb
# 6  GSE102092_ATAC-Dev-Ret_M_N-P10.free.bw    mm9    267.8 Mb
# 7  GSE102092_ATAC-Dev-Ret_M_N-P14.free.bw    mm9    169.6 Mb
# 8  GSE102092_ATAC-Dev-Ret_M_N-P21.free.bw    mm9    156.4 Mb
# 9  GSE102092_ATAC-Dev-Ret_M_N-P7.free.bw     mm9    197.6 Mb
#
# To download one of these tracks, use download_tracks(track_num=X) where X is the track number / index.
# You can specify your own download url by download_tracks(url='X').

# %%
scanobject.download_tracks(track_num=1)
# Out:
# This track already exists!

# %%
scanobject.load_track('GSE102092_ATAC-Dev-Ret_E_N-E14.5.free.mm10.bw.bw', 'mm10')
scanobject.enhancer_scanner('chr14:48654006-48677663')
scanobject.plot_detected_enhancers()
# Out:
# Max peak height in this range:  28.005199432373047
# Mean peak height in this range:  1.5306871556017858
# Median peak height in this range:  0.8751630187034607
#
# Max peak height across whole track:  1173
# Minumum peak height across whole track:  0
#
# Using auto detection of peak height:  7.001299858093262
#
# Total Peaks Detected: 10
# Final Passed Merge/Filters: 7
