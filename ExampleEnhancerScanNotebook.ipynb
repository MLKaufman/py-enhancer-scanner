# %% [markdown]
# # pyEnhancerScan Package Example Notebook

# %%
from pyEnhancerScan import EnhancerScan
scanobject = EnhancerScan()
# Out:
# pyEnhancerScanner version 0.4 beta
#
# The following tracks are locally available:
#
# To download additional tracks, use the download_tracks() function.

# %%
scanobject.download_tracks()
# Out:
# External Track List:
#                                       Track_Name Genome  Size
# 0          60way.phastCons60wayPlacental.mm10.bw   mm10  4.4G
# 1            GSE102092_Retina_E14.5_ATAC.mm10.bw   mm10  232M
# 2               GSE102092_Retina_P0_ATAC.mm10.bw   mm10  267M
# 3               GSE102092_Retina_P7_ATAC.mm10.bw   mm10  203M
# 4              GSE102092_Retina_P21_ATAC.mm10.bw   mm10  158M
# 5    GSM499736_Retina_CRX_ChiPseq_lowres.mm10.bw   mm10   25M
# 6  GSM1306912_Retina_OTX2_ChIPseq_lowres.mm10.bw   mm10   66M
# 7    GSM4008316_Retina_P12_ASCL1_ChIPseq.mm10.bw   mm10  174M
#
# To download one of these tracks, use download_tracks(track_num=X) where X is the track number / index.
# You can specify your own download url by download_tracks(url='X').

# %%
scanobject.download_tracks(1)
# Out:
# Downloading  GSE102092_Retina_E14.5_ATAC.mm10.bw ...
# Download successful!

# %%
scanobject.load_track('GSE102092_Retina_E14.5_ATAC.mm10.bw', 'mm10')
scanobject.enhancer_scanner('chr14', 48663821, 48877891, peak_height=10)
scanobject.plot_detected_enhancers()
# Out:
# Max peak height in this range:  28.005199432373047
# Mean peak height in this range:  0.6609675954633168
# Median peak height in this range:  0.0
#
# Max peak height across whole track:  1173
# Minumum peak height across whole track:  0
#
# Total Peaks Detected: 13
# Final Passed Merge/Filters: 9

# %%
scanobject.plot_detected_size()

# %%
scanobject.plot_detected_mean_peak_values()

# %%
scanobject.plot_detected_max_peak_values()

# %%
scanobject.motif_scanner('OTX2+VSX2', plot=True)
# Out:
# OTX2+VSX2
