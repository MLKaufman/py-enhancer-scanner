# %% [markdown]
# # pyEnhancerScan Package Example Notebook

# %%
from pyEnhancerScan import EnhancerScan
scanobject = EnhancerScan()
# Out:
# pyEnhancerScanner version 0.2 beta
# The following tracks are available:
#
# None
#
# Ability to load remote files:  0

# %%
scanobject.load_track('../data/GSE102092_ATAC-Dev-Ret_E_N-E14.5.free.mm10.bw.bw', 'mm10')
scanobject.enhancer_scanner('chr14', 48663821, 48877891, peak_height=10)
scanobject.plot_detected_enhancers()
# Out:
# Max peak height in this range:  28.005199432373047
# Max peak height in whole track:  1173
# Minumum peak height in dataset:  0
#
# Total Peaks Detected: 13
# [(48664784, 48665285), (48665296, 48665944), (48665972, 48666743), (48668706, 48669247), (48673523, 48673938), (48709440, 48710045), (48709870, 48710045), (48738267, 48738666), (48740973, 48741271), (48740973, 48741544), (48754001, 48754525), (48799561, 48800117), (48815399, 48815720)]
# Final Passed Merge/Filters: 9

# %%
scanobject.plot_detected_size()

# %%
scanobject.plot_detected_mean_peak_values()

# %%
scanobject.plot_detected_max_peak_values()

# %%
scanobject.write_genbank('enhancers')
# Out:
# 48664784
# 48668706
# 48673523
# 48709440
# 48738267
# 48740973
# 48754001
# 48799561
# 48815399
